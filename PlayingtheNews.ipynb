# %%
# import libraries
import spotipy
import webbrowser
import json
import urllib.request
import geocoder
from nltk.corpus import stopwords
import spotipy.util as util
import random

# %%
with open("news_keys.txt", "r") as file:
    key = file.read()

# %%
country = 'us'
url = ('https://newsapi.org/v2/top-headlines?country=us&apiKey=' + key) #change the url from newsAPI
request = urllib.request.Request(url)
response = urllib.request.urlopen(request)

# %%
type(response)
# Out:
# http.client.HTTPResponse

# %%
# converting the HTTPResponse object to a python dictionary
headlines = json.loads(response.read())

# %%
# make an empty list
article_titles = []
for headline in headlines['articles']:
    article_titles.append(headline['title'])

# %%
article_titles
# Out:
# ['Virginia Congressman Donald McEachin dies at 61 - The Washington Post',
#  'Iran faces USMNT in winner-takes-all match to progress to World Cup knockout stages - CNN',
#  'All the Best Cyber Monday Video Game Deals for 2022 - IGN',
#  "Teen who allegedly confessed on Instagram video chat to killing girl told police it was an 'accident,' complaint says - CNN",
#  'Clarence Gilyard, Jr Dies: ‘Walker, Texas Ranger,’ ‘Die Hard’ Star Was 66 - Deadline',
#  'China Covid: Police clamp down after days of protests - BBC',
#  'Mauna Loa eruption prompts officials to warn of a worst-case scenario - USA TODAY',
#  'App Store Awards celebrate the best apps and games of 2022 - Apple',
#  'Kenny Pickett, Steelers squander lead but close out Colts - ESPN',
#  '‘Everything Everywhere All at Once’ Tops Gotham Awards; Full Winners List - Hollywood Reporter',
#  'Hailey Bieber Shows Her Ovarian Cyst “the Size of an Apple” - E! NEWS',
# ...

# %%
# go through each title/headline
for headline in article_titles:
    print(headline)
    # go through each line to ech title
# Out:
# Virginia Congressman Donald McEachin dies at 61 - The Washington Post
# Iran faces USMNT in winner-takes-all match to progress to World Cup knockout stages - CNN
# All the Best Cyber Monday Video Game Deals for 2022 - IGN
# Teen who allegedly confessed on Instagram video chat to killing girl told police it was an 'accident,' complaint says - CNN
# Clarence Gilyard, Jr Dies: ‘Walker, Texas Ranger,’ ‘Die Hard’ Star Was 66 - Deadline
# China Covid: Police clamp down after days of protests - BBC
# Mauna Loa eruption prompts officials to warn of a worst-case scenario - USA TODAY
# App Store Awards celebrate the best apps and games of 2022 - Apple
# Kenny Pickett, Steelers squander lead but close out Colts - ESPN
# ‘Everything Everywhere All at Once’ Tops Gotham Awards; Full Winners List - Hollywood Reporter
# Hailey Bieber Shows Her Ovarian Cyst “the Size of an Apple” - E! NEWS
# Hugh Freeze in position to succeed quickly at Auburn amid modern college football landscape - CBS Sports
# ...

# %%
article_titles[0]
for word in article_titles[0].split(" "):
    print(word)
# Out:
# Virginia
# Congressman
# Donald
# McEachin
# dies
# at
# 61
# -
# The
# Washington
# Post

# %%
unique_words = set()
for headline in headlines['articles']:
    for word in headline['title'].lower().split():
        if word not in stopwords.words('english') and word.isalpha():
            unique_words.add(word)
            
unique_words
# Out:
# {'allegedly',
#  'amid',
#  'angeles',
#  'app',
#  'apple',
#  'apps',
#  'artemis',
#  'athletic',
#  'auburn',
#  'awards',
#  'az',
#  'bbc',
#  'best',
#  'bieber',
#  'cbs',
#  'celebrate',
#  'certifies',
#  'chat',
#  'china',
#  'clamp',
#  'clarence',
#  'close',
#  'cnn',
#  'cochise',
#  'college',
#  'colts',
#  'complaint',
#  'confessed',
#  'congressman',
#  'cop',
#  'county',
#  'cup',
#  'cyber',
#  'cyst',
#  'days',
#  'deadline',
#  'deals',
#  'dies',
#  'distance',
#  'donald',
#  'earth',
#  'eruption',
#  'espn',
#  'everywhere',
#  'faces',
#  'fans',
#  'fear',
#  'female',
#  'football',
#  'fox',
#  'freeze',
#  'full',
#  'game',
#  'games',
#  'girl',
#  'gotham',
#  'hailey',
#  'hollywood',
#  'hugh',
#  'ign',
#  'instagram',
#  'iran',
#  'jr',
#  'kenny',
#  'killing',
#  'knockout',
#  'landscape',
#  'lead',
#  'list',
#  'livenow',
#  'loa',
#  'los',
#  'maricopa',
#  'match',
#  'mauna',
#  'mceachin',
#  'midterm',
#  'mission',
# ...

# %%
article_titles[0]
for word in article_titles[0].lower().split(" "):
    if word not in stopwords.words('english') and word.isalpha():
        print(word)
# Out:
# virginia
# congressman
# donald
# mceachin
# dies
# washington
# post

# %%
list_of_words = []
for title in article_titles:
    # go through each words
    for word in article_titles[0].lower().split(" "):
    # is the word not a stopword?
    # is the word not a number?
        if word not in stopwords.words('english') and word.isalpha():
            list_of_words.append(word)

# %%
# open file with keys and set the path to your credentials JSON file
credentials = "spotify_keys.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]
redirectURI = api_tokens["redirect"]
username = api_tokens["username"]

# %%
scope = 'user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public user-library-read'
token = util.prompt_for_user_token(username, scope, client_id=client_id,
                           client_secret=client_secret,
                           redirect_uri=redirectURI)

# %%
# create my spotify object
sp = spotipy.Spotify(auth=token)

# %%
for keyword in list(unique_words):
    #search for artists based on my keyword, only give me one artist
    searchResults = sp.search(q="artist:" + keyword, type="track", limit=1)
    print(searchResults)
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=artist%3Avideo&type=track&offset=0&limit=1', 'items': [{'album': {'album_type': 'single', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3rp4f58JlRHkk8hpdLCer1'}, 'href': 'https://api.spotify.com/v1/artists/3rp4f58JlRHkk8hpdLCer1', 'id': '3rp4f58JlRHkk8hpdLCer1', 'name': 'Videoclub', 'type': 'artist', 'uri': 'spotify:artist:3rp4f58JlRHkk8hpdLCer1'}], 'available_markets': ['AE', 'AG', 'AL', 'AM', 'AO', 'AR', 'AT', 'AU', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH', 'BI', 'BJ', 'BN', 'BO', 'BR', 'BS', 'BT', 'BW', 'BY', 'BZ', 'CA', 'CD', 'CG', 'CH', 'CI', 'CL', 'CM', 'CO', 'CR', 'CV', 'CW', 'CY', 'CZ', 'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'ES', 'FI', 'FJ', 'FM', 'GA', 'GB', 'GD', 'GE', 'GH', 'GM', 'GN', 'GQ', 'GR', 'GT', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL', 'IN', 'IQ', 'IS', 'IT', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI', 'KM', 'KN', 'KR', 'KW', 'KZ', 'LA', 
# ...

# %%
searchResults = sp.search(q="artist:" + 'Dylon', type="track",limit=1)
if len(searchResults['tracks']['items']) > 0:
    first_song = searchResults['tracks']['items'][0]

# %%
# uniform resourses identifier - uri
searchResult = sp.search(q="artist:" + 'Dylon', type="track")
searchResult['tracks']['items'][0]['uri']
# Out:
# 'spotify:track:2sEj9yv59hEbplLlXTp3hB'

# %%
songs_for_playlist = []
for keyword in list(unique_words):
    #search for artists based on my keyword, only give me one artist
    searchResult = sp.search(q="artist:" + 'Dylon', type="track", limit=1)
    #if the search returns anything 
    if len(searchResults['tracks']['items']) > 0:
        songs_for_playlist.append(searchResults['tracks']['items'][0]['uri'])
print(songs_for_playlist)
# Out:
# ['spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu', 'spotify:track:693kM2e0VGAe0pkqtcdrAu
# ...

# %%
random.choice(list_of_words)
# Out:
# 'washington'

# %%
songs_for_palylist = []
# have for loop run 50 times
for keyword in range(50):
    # pick a random keyword
    new_keyword = random.choice(list_of_words)
    # search for artists based on my keyword, only give me one artist
        searchResult = sp.search(q="artist:"+'Dylon', type="track", limit=1)
    # if the search returns everything
print(searchResult)
# Out:
#   Cell In[203], line 7
#     searchResult = sp.search(q="artist:"+'Dylon', type="track", limit=1)
#     ^
# IndentationError: unexpected indent

# %%
random.choice(list_of_words)
# Out:
# 'congressman'

# %%
my_playlist = {}
# go through each title
    for title in my_playlist:
        my_playlist = sp.user_playlist_create(user=username, name+"Todays News", public=True, description="Songs for the news")
        results = sp.user_playlist_add_tracks(username, my_playlist['Dylon'], songs)
        print(results)
# Out:
#   Cell In[215], line 3
#     for title in my_playlist:
#     ^
# IndentationError: unexpected indent

# %%
type(my_playlist)
# Out:
# dict

# %%
# print out token
token
# Out:
# 'BQCvT2wiWiV_n7AZrxN6aYG7gXNtvLCHYyAPggwX_k_alb8LrR2ue_m2Qk7z0VgO1hZdGF54bW4qEDNupHGyQzfkgGxThDGmjQc7EHPZv1Tx97NJjF28eJ3dzevch6I6LcDx5L8uygCzIos-zEKJ5sll3hNTy1DUxFGFf3yxrwxc0KIHlSO02rB83ZcoJgofTuI97SFM-KqDuKVknjCow0HyJqKrmCiQSzYEVEVF'
